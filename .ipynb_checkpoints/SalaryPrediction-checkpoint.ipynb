# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("./survey_results_public.csv")

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df = df[["Country", "MainBranch", "Age", "EdLevel", "WorkExp", "ConvertedCompYearly"]]
df = df.rename({"ConvertedCompYearly": "Salary"}, axis=1)
df.head()
# Out:
#                     Country                      MainBranch              Age  \
# 0                       NaN                   None of these  18-24 years old
# 1  United States of America  I am a developer by profession  25-34 years old
# 2  United States of America  I am a developer by profession  45-54 years old
# 3  United States of America  I am a developer by profession  25-34 years old
# 4               Philippines  I am a developer by profession  25-34 years old
#
#                                         EdLevel  WorkExp    Salary
# 0                                           NaN      NaN       NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)     10.0  285000.0
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)     23.0  250000.0
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)      7.0  156000.0
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)      6.0   23456.0

# %%
df.isnull().sum()
# Out:
# Country        1211
# MainBranch        0
# Age               0
# EdLevel        1211
# WorkExp       45605
# Salary        41165
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Country       0
# MainBranch    0
# Age           0
# EdLevel       0
# WorkExp       0
# Salary        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32638 entries, 1 to 89171
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     32638 non-null  object
#  1   MainBranch  32638 non-null  object
#  2   Age         32638 non-null  object
#  3   EdLevel     32638 non-null  object
#  4   WorkExp     32638 non-null  float64
#  5   Salary      32638 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.7+ MB

# %%
cate = df['Country'].value_counts()
cate
# Out:
# Country
# United States of America                                8013
# Germany                                                 2689
# United Kingdom of Great Britain and Northern Ireland    2312
# India                                                   1516
# Canada                                                  1427
#                                                         ...
# Malawi                                                     1
# Guinea-Bissau                                              1
# Gabon                                                      1
# Tajikistan                                                 1
# Antigua and Barbuda                                        1
# Name: count, Length: 163, dtype: int64

# %%
cate.index[0], cate.values[0]
# Out:
# ('United States of America', 8013)

# %%
cate[0]
# Out:
# /var/folders/8m/wbm3_2nn5kb5c8qtz5bb8blc0000gn/T/ipykernel_45264/941444705.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cate[0]
# 8013

# %%
def shorten_categories(categories, cutoff):
    categorical_map = {}
    for i in range(len(categories)):
        if categories[i] > cutoff:
            categorical_map[categories.index[i]] = categories.index[i]
        else:
            categorical_map[categories.index[i]] = 'Other'
    return categorical_map

# %%
country_map = shorten_categories(df.Country.value_counts(), 400)
df['Country'] = df['Country'].map(country_map)
df.Country.value_counts()
# Out:
# /var/folders/8m/wbm3_2nn5kb5c8qtz5bb8blc0000gn/T/ipykernel_45264/379764975.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if categories[i] > cutoff:
# Country
# Other                                                   9622
# United States of America                                8013
# Germany                                                 2689
# United Kingdom of Great Britain and Northern Ireland    2312
# India                                                   1516
# Canada                                                  1427
# France                                                  1076
# Poland                                                   918
# Brazil                                                   916
# Netherlands                                              837
# ...

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df = df[df['Salary'] < 500000] 
df = df[df['Country'] != 'Other']

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df['EdLevel'].unique()
# Out:
# array(['Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Some college/university study without earning a degree',
#        'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Professional degree (JD, MD, Ph.D, Ed.D, etc.)',
#        'Associate degree (A.A., A.S., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Something else', 'Primary/elementary school'], dtype=object)

# %%
 def clean_education(x):
    if "Bachelor’s degree" in x:
        return "Bachelor’s degree"
    if "Master’s degree" in x:
        return "Master’s degree"
    if "Professional degree" in x:
        return "Professional degree"
    return "Less than a Bachelors"

# %%
df['EdLevel'] = df['EdLevel'].apply(clean_education)
df['EdLevel'].unique()
# Out:
# array(['Bachelor’s degree', 'Less than a Bachelors', 'Master’s degree',
#        'Professional degree'], dtype=object)

# %%
# df['Age'].unique()

# %%
# age_map = {'Under 18 years old': 17,
#            '18-24 years old': 20,
#            '25-34 years old': 30,
#            '35-44 years old': 40,
#            '45-54 years old': 50,
#            '55-64 years old': 60,
#            '65 years or older':65,
#            'Prefer not to say': 0
#           }
# df['Age'] = df['Age'].map(age_map)

# %%
# df['Age'].unique()

# %%
from sklearn.preprocessing import LabelEncoder

le_country = LabelEncoder()
df['Country'] = le_country.fit_transform(df['Country'])
le_mainbranch = LabelEncoder()
df['MainBranch'] = le_mainbranch.fit_transform(df['MainBranch'])
le_age = LabelEncoder()
df['Age'] = le_age.fit_transform(df['Age'])
le_edlevel = LabelEncoder()
df['EdLevel'] = le_edlevel.fit_transform(df['EdLevel'])

# %%
df.head()
# Out:
#    Country  MainBranch  Age  EdLevel  WorkExp    Salary
# 1       13           0    1        0     10.0  285000.0
# 2       13           0    3        0     23.0  250000.0
# 3       13           0    1        0      7.0  156000.0
# 5       12           0    2        1     22.0   96828.0
# 6       13           0    2        1      4.0  135000.0

# %%
X = df.drop('Salary', axis=1)
y = df['Salary']

# %%
# LinearRegression model
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X, y.values)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

y_pred = linear_reg.predict(X)
error = np.sqrt(mean_squared_error(y, y_pred))
print(f"${error:.2f}")
# Out:
# $60072.77

# %%
# DecisionTree model
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor()
dt_reg.fit(X, y.values)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt_reg.predict(X)
error = np.sqrt(mean_squared_error(y, y_pred))
print(f"${error:.2f}")
# Out:
# $45693.39

# %%
# RandomForest model
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor(random_state=1)
rf_reg.fit(X, y.values)
# Out:
# RandomForestRegressor(random_state=1)

# %%
y_pred = rf_reg.predict(X)
error = np.sqrt(mean_squared_error(y, y_pred))
print(f"${error:.2f}")
# Out:
# $46081.77

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None, 2,4,6,8,10,12]
parameters = {"max_depth": max_depth}

regressor = DecisionTreeRegressor(random_state=0)
gs = GridSearchCV(regressor, parameters, scoring="neg_mean_squared_error")
gs.fit(X, y.values)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'max_depth': [None, 2, 4, 6, 8, 10, 12]},
#              scoring='neg_mean_squared_error')

# %%
regressor = gs.best_estimator_

regressor.fit(X, y.values)
y_pred = regressor.predict(X)
error = np.sqrt(mean_squared_error(y, y_pred))
print(f"${error:.2f}")
# Out:
# $49598.59

# %%
x_test = np.array([["United States of America", "I am a developer by profession", "25-34 years old", "Master’s degree", 5]])
x_test
# Out:
# array([['United States of America', 'I am a developer by profession',
#         '25-34 years old', 'Master’s degree', '5']], dtype='<U30')

# %%
x_test[:, 0] = le_country.transform(x_test[:, 0])
x_test[:, 1] = le_mainbranch.transform(x_test[:, 1])
x_test[:, 2] = le_age.transform(x_test[:, 2])
x_test[:, 3] = le_edlevel.transform(x_test[:, 3])

y_pred = dt_reg.predict(x_test)
y_pred
# Out:
# /Users/yutowilliam/anaconda3/envs/ml/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([143051.75438596])

# %%
y_pred = rf_reg.predict(x_test)
y_pred
# Out:
# /Users/yutowilliam/anaconda3/envs/ml/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([143933.03643676])

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# /Users/yutowilliam/anaconda3/envs/ml/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([144809.20670391])

# %%
import pickle

data = {'model': rf_reg, 'le_country': le_country, 'le_mainbranch': le_mainbranch, 'le_age': le_age,
        'le_edlevel': le_edlevel}
with open('saved_steps.pkl', 'wb') as file:
    pickle.dump(data, file)
